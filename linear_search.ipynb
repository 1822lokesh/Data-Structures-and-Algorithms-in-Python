# %% [markdown]
# <a href="https://colab.research.google.com/github/1822lokesh/Data-Structures-and-Algorithms-in-Python/blob/main/linear_search.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Linear Serach
#
# Linear Search is a simple searching algorithm that checks each element in the list one by one until the target element is found or the list ends.
#
# **Steps**
#
# * Start from the first element.
# * Compare with the target.
# * If found, return the index.
# * If not found, return -1.
#
#
# **Time Complexity**
#
#
# * Best Case: O(1)
# * Worst Case: O(n)
# * Average Case: O(n)
# * Space Complexity: O(1)
#
# Example
# Array: [10, 20, 30, 40, 50]
#
# Target: 30
#
# Output: Element found at index 2

# %%
def linear_search(arr, key):
    for i in range(len(arr)):
        if arr[i] == key:
            return i
    return -1

# Example usage
arr = [10, 20, 30, 40, 50]
key = 30
result = linear_search(arr, key)

if result != -1:
    print(f"Element found at index {result}")
else:
    print("Element not found")
# Out:
# Element found at index 2
